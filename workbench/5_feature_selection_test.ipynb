# %% [markdown]
# ## `Flight Delay Prediction`
# ### **Part 2:** Data Cleaning and Feature Selection
#
# Ali Bahrami

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go


from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %matplotlib inline

# %%
# Read from extracted data
df = pd.read_csv("data/flights_test.csv")

# %%
# Perform all the operations conducted on training data to the evaluation data.
# To save time, df_flights in this notebook is taken from flights_test
df_flights = df.copy()
df_flights.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2020-01-01                 WN                 WN          WN
# 1  2020-01-01                 WN                 WN          WN
# 2  2020-01-01                 WN                 WN          WN
# 3  2020-01-01                 WN                 WN          WN
# 4  2020-01-01                 WN                 WN          WN
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                5888                WN   N951WN               5888
# 1                6276                WN   N467WN               6276
# 2                4598                WN   N7885A               4598
# 3                4761                WN   N551WN               4761
# 4                5162                WN   N968WN               5162
#
#    origin_airport_id origin origin_city_name  dest_airport_id dest  \
# 0              13891    ONT      Ontario, CA            14771  SFO
# 1              13891    ONT      Ontario, CA            14771  SFO
# 2              13891    ONT      Ontario, CA            14831  SJC
# 3              13891    ONT      Ontario, CA            14831  SJC
# 4              13891    ONT      Ontario, CA            14831  SJC
#
#       dest_city_name  crs_dep_time  crs_arr_time dup  crs_elapsed_time  \
# 0  San Francisco, CA          1810          1945   N                95
# 1  San Francisco, CA          1150          1320   N                90
# 2       San Jose, CA          2020          2130   N                70
# 3       San Jose, CA          1340          1455   N                75
# 4       San Jose, CA           915          1035   N                80
#
#    flights  distance
# 0        1       363
# 1        1       363
# 2        1       333
# 3        1       333
# 4        1       333

# %%
# The airlines names are given as abbreviations only, import the full name from the files.
airlines = pd.read_csv("data/airlines.csv")
abbr_airlines = airlines.set_index('IATA_CODE')['AIRLINE'].to_dict()

# Add the full airline names to the dataframe
df_flights['carrier'] = df_flights['mkt_unique_carrier'].replace(abbr_airlines)


# Add separate columns for year, month, day of month, and day of week
df_flights['fl_date'] = pd.to_datetime(df_flights['fl_date'],format='%Y-%m-%d')
df_flights['month'] = pd.DatetimeIndex(df_flights['fl_date']).month
df_flights['day_of_week'] = pd.DatetimeIndex(df_flights['fl_date']).dayofweek

# %%
def bin_hours(time):
    # Bin the time from HHMM input format to 24 hrs where 23=11pm and 0=12am
    if type(time) == 'numpy.ndarray':
        time = time.astype(int)
    time = int(time)
    
    t = time // 100
    
    if t == 0:
        return 0
    return t

# Bin the departure time into hours
df_flights.loc[:,'crs_dep_time'] = df_flights['crs_dep_time'].apply(bin_hours)
df_flights.loc[:,'crs_arr_time'] = df_flights['crs_arr_time'].apply(bin_hours)

# %%
mean_hist_dep_delay = pd.read_csv("data/mean_hist_dep_delay.csv")
mean_hist_arr_delay = pd.read_csv("data/mean_hist_arr_delay.csv")

# %%
merged = pd.merge(df_flights, mean_hist_dep_delay, on=['crs_dep_time'], how='left')
df_flights = pd.merge(merged, mean_hist_arr_delay, on=['crs_arr_time'], how='left')

# %%
df_flights.head()
# Out:
#      fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0 2020-01-01                 WN                 WN          WN
# 1 2020-01-01                 WN                 WN          WN
# 2 2020-01-01                 WN                 WN          WN
# 3 2020-01-01                 WN                 WN          WN
# 4 2020-01-01                 WN                 WN          WN
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                5888                WN   N951WN               5888
# 1                6276                WN   N467WN               6276
# 2                4598                WN   N7885A               4598
# 3                4761                WN   N551WN               4761
# 4                5162                WN   N968WN               5162
#
#    origin_airport_id origin  ... crs_arr_time  dup crs_elapsed_time flights  \
# 0              13891    ONT  ...           19    N               95       1
# 1              13891    ONT  ...           13    N               90       1
# 2              13891    ONT  ...           21    N               70       1
# 3              13891    ONT  ...           14    N               75       1
# 4              13891    ONT  ...           10    N               80       1
#
#    distance             carrier month  day_of_week  mean_hist_dep_delay  \
# 0       363  Southwest Airlines     1            2            10.983196
# 1       363  Southwest Airlines     1            2             4.860123
# 2       333  Southwest Airlines     1            2            11.688123
# 3       333  Southwest Airlines     1            2             6.750271
# 4       333  Southwest Airlines     1            2             3.246698
#
#    mean_hist_arr_delay
# 0             5.387877
# 1            -0.927422
# 2             5.265583
# 3             0.053946
# 4            -3.180434
#
# [5 rows x 25 columns]

# %%
## We had included the air_time by error and to complete the assignment, I am gonna input the mean here, but this needs to be fixed
df_flights.insert (6, "air_time", 107.6973116856836)

# %%
df_flights = df_flights[['origin', 'dest', 'crs_dep_time', 'crs_arr_time',
       'crs_elapsed_time', 'air_time', 'distance', 'carrier', 'month',
       'day_of_week', 'mean_hist_dep_delay', 'mean_hist_arr_delay']]

df_flights.head()
# Out:
#   origin dest  crs_dep_time  crs_arr_time  crs_elapsed_time    air_time  \
# 0    ONT  SFO            18            19                95  107.697312
# 1    ONT  SFO            11            13                90  107.697312
# 2    ONT  SJC            20            21                70  107.697312
# 3    ONT  SJC            13            14                75  107.697312
# 4    ONT  SJC             9            10                80  107.697312
#
#    distance             carrier  month  day_of_week  mean_hist_dep_delay  \
# 0       363  Southwest Airlines      1            2            10.983196
# 1       363  Southwest Airlines      1            2             4.860123
# 2       333  Southwest Airlines      1            2            11.688123
# 3       333  Southwest Airlines      1            2             6.750271
# 4       333  Southwest Airlines      1            2             3.246698
#
#    mean_hist_arr_delay
# 0             5.387877
# 1            -0.927422
# 2             5.265583
# 3             0.053946
# 4            -3.180434

# %% [markdown]
# ## Label Encode

# %%
# Origin
le_origin = LabelEncoder()
le_origin.fit(df_flights.origin)
df_flights.loc[:,"origin"] = le_origin.transform(df_flights.origin)

# %%
# Dest
le_dest = LabelEncoder()
le_dest.fit(df_flights.dest)
df_flights.loc[:,"dest"] = le_dest.transform(df_flights.dest)

# %%
# Carrier
le_carrier = LabelEncoder()
le_carrier.fit(df_flights.carrier)
df_flights.loc[:,"carrier"] = le_carrier.transform(df_flights.carrier)

# %%
df_flights.dtypes
# Out:
# origin                   int64
# dest                     int64
# crs_dep_time             int64
# crs_arr_time             int64
# crs_elapsed_time         int64
# air_time               float64
# distance                 int64
# carrier                  int64
# month                    int64
# day_of_week              int64
# mean_hist_dep_delay    float64
# mean_hist_arr_delay    float64
# dtype: object

# %%
df_flights.head()
# Out:
#    origin  dest  crs_dep_time  crs_arr_time  crs_elapsed_time    air_time  \
# 0     246   312            18            19                95  107.697312
# 1     246   312            11            13                90  107.697312
# 2     246   318            20            21                70  107.697312
# 3     246   318            13            14                75  107.697312
# 4     246   318             9            10                80  107.697312
#
#    distance  carrier  month  day_of_week  mean_hist_dep_delay  \
# 0       363        7      1            2            10.983196
# 1       363        7      1            2             4.860123
# 2       333        7      1            2            11.688123
# 3       333        7      1            2             6.750271
# 4       333        7      1            2             3.246698
#
#    mean_hist_arr_delay
# 0             5.387877
# 1            -0.927422
# 2             5.265583
# 3             0.053946
# 4            -3.180434

# %%
df_flights.shape
# Out:
# (150623, 12)

# %% [markdown]
# ## Scale the data and prepare it for modeling

# %%
df_model = df_flights.copy()

# %%
X = df_model

# %%
scaler = StandardScaler()
scaler.fit(X)
scaled_df = scaler.fit_transform(X)

# %%
df_flights.columns
# Out:
# Index(['origin', 'dest', 'crs_dep_time', 'crs_arr_time', 'crs_elapsed_time',
#        'air_time', 'distance', 'carrier', 'month', 'day_of_week',
#        'mean_hist_dep_delay', 'mean_hist_arr_delay'],
#       dtype='object')

# %%
flights_scaled = pd.DataFrame(data = scaled_df,
              columns = ['origin', 'dest', 'crs_dep_time', 'crs_arr_time',
       'crs_elapsed_time', 'air_time', 'distance', 'carrier', 'month',
       'day_of_week', 'mean_hist_dep_delay', 'mean_hist_arr_delay'])

# %%
flights_scaled
# Out:
#           origin      dest  crs_dep_time  crs_arr_time  crs_elapsed_time  \
# 0       0.701911  1.378212      1.002153      0.847341         -0.660447
# 1       0.701911  1.378212     -0.420511     -0.298153         -0.728836
# 2       0.701911  1.439675      1.408629      1.229172         -1.002392
# 3       0.701911  1.439675     -0.014036     -0.107237         -0.934003
# 4       0.701911  1.439675     -0.826987     -0.870900         -0.865614
# ...          ...       ...           ...           ...               ...
# 150618 -0.803562 -0.014950      0.798916      0.847341         -0.359536
# 150619 -0.373427  0.189926     -1.436700     -1.443647         -0.332181
# 150620 -1.612626  1.849429      0.798916      0.656425         -0.304825
# 150621  1.848939 -1.612989      1.002153      1.229172         -0.400570
# 150622  1.080840  0.189926     -1.436700     -1.443647         -0.578381
#
#             air_time  distance   carrier  month  day_of_week  \
# 0      -2.842171e-14 -0.717995  0.775433    0.0    -0.495615
# 1      -2.842171e-14 -0.717995  0.775433    0.0    -0.495615
# 2      -2.842171e-14 -0.768505  0.775433    0.0    -0.495615
# 3      -2.842171e-14 -0.768505  0.775433    0.0    -0.495615
# 4      -2.842171e-14 -0.768505  0.775433    0.0    -0.495615
# ...              ...       ...       ...    ...          ...
# 150618 -2.842171e-14 -0.472176 -0.592137    0.0    -0.991589
# 150619 -2.842171e-14 -0.302124 -0.592137    0.0    -0.991589
# 150620 -2.842171e-14 -0.337481 -0.592137    0.0    -0.991589
# 150621 -2.842171e-14 -0.337481 -0.592137    0.0    -0.991589
# 150622 -2.842171e-14 -0.876261 -0.592137    0.0    -0.991589
#
#         mean_hist_dep_delay  mean_hist_arr_delay
# 0                  1.205286             1.138352
# 1                 -0.331726            -0.534287
# 2                  1.382236             1.105962
# 3                  0.142738            -0.274366
# 4                 -0.736727            -1.131008
# ...                     ...                  ...
# 150618             0.980384             1.138352
# 150619            -1.738414            -1.716762
# 150620             0.980384             0.922617
# 150621             1.205286             1.105962
# 150622            -1.738414            -1.716762
#
# [150623 rows x 12 columns]

# %%
# This is the scaled test data that we will use to predict the model on.
flights_scaled.to_csv("data/test_eval.csv", index=False)
